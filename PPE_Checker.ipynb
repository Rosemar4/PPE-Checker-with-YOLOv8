# %% [markdown]
# <a href="https://colab.research.google.com/github/Rosemar4/PPE-Checker-with-YOLOv8/blob/main/PPE_Checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
# !yolo detect train data="/content/drive/MyDrive/Computer Vision Projects/PPE Checker/data.yaml" model=yolov8n.pt epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
